# %%
import sys
from pathlib import Path

# %%
#Agregar la carpeta raíz del proyecto al path
ROOT = Path.cwd().parent #notebooks/ -> sube un nivel al proyecto
sys.path.append(str(ROOT))

# %%
#Path.cwd() → estás parado en notebooks/
#.parent -> sube a churn-prediction/
#Eso permite que from src.preprocessing import Preprocessor funcione

# %%
from src.preprocessing import (
    load_and_clean_data,
    split_features_target,
    build_preprocessor,
    split_data,
    save_preprocessor
)

# %%
# 1. Cargar y limpiar
df = load_and_clean_data("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
# 2. Separar X, y y columnas  
X, y, cat_cols, num_cols = split_features_target(df)

# %%
# 3. Dividir en train/val/test
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X,y)

# %%
## 4. Crear y ajustar preprocesador
preprocessor = build_preprocessor(cat_cols, num_cols)
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['SeniorCitizen', 'tenure', 'MonthlyCharges',
#                                   'TotalCharges']),
#                                 ('cat',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['gender', 'Partner', 'Dependents',
#                                   'PhoneService', 'MultipleLines',
#                                   'InternetService', 'OnlineSecurity',
#                                   'OnlineBackup', 'DeviceProtection',
#                                   'TechSupport', 'StreamingTV',
#                                   'StreamingMovies', 'Contract',
# ...

# %%
# 5. Transformar los sets
X_train = preprocessor.transform(X_train)
X_val_pre = preprocessor.transform(X_val)
X_test_pre = preprocessor.transform(X_test)

# %%
save_preprocessor(preprocessor, "../models/preprocessor.joblib")
